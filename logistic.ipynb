# %%
from sklearn.linear_model import LogisticRegression

classifier= LogisticRegression(solver='lbfgs')

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
    'penalty': ['l2', 'none'],  # Only include penalties compatible with lbfgs
    'C': [1, 2, 3, 4, 5, 6, 10, 20, 30, 40, 50],
    'max_iter': [100, 200, 300]
}

# %%
classifier_regressor=GridSearchCV(classifier,param_grid=parameters,scoring='accuracy',cv=5)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the training and test data
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# Encode the 'Gender' column in both training and test data
label_encoder = LabelEncoder()
train_data['Gender'] = label_encoder.fit_transform(train_data['Gender'])
test_data['Gender'] = label_encoder.transform(test_data['Gender'])

# Define column names
column_names = ['Gender', 'Age', 'openness', 'neuroticism', 'conscientiousness', 'agreeableness', 'extraversion', 'Personality (class label)']

# Assign column names to both datasets
train_data.columns = column_names
test_data.columns = column_names

# Split features and target variables
x_train = train_data.drop('Personality (class label)', axis=1)
y_train = train_data['Personality (class label)']

x_test = test_data.drop('Personality (class label)', axis=1)
y_test = test_data['Personality (class label)']

# %%
classifier_regressor.fit(x_train,y_train)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# D:\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
print(classifier_regressor.best_params_)
# Out:
# {'C': 1, 'max_iter': 100, 'penalty': 'none'}

# %%
y_pred=classifier_regressor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.7714285714285715

# %%
from sklearn.metrics import precision_score

# %%
classifier_regressor.fit(x_train, y_train)
y_pred = classifier_regressor.predict(x_test)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# D:\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
accuracy = accuracy_score(y_pred, y_test)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred, average='weighted')  # You can specify the average parameter as needed
print("Precision:", precision)
# Out:
# Accuracy: 0.7714285714285715
# Precision: 0.7759700176366844

# %%
from sklearn.metrics import recall_score, f1_score
# Calculate recall
recall = recall_score(y_test, y_pred, average='weighted')  # You can specify the average parameter as needed
print("Recall:", recall)

# Calculate F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # You can specify the average parameter as needed
print("F1 Score:", f1)
# Out:
# Recall: 0.7714285714285715
# F1 Score: 0.7594416905022577

# %%
import matplotlib.pyplot as plt

# Given data
algorithms = ['Logistic Regression', 'Naive Bayes', 'Random Forest', 'K Nearest Neighbor', 'Decision Tree']
accuracy = [0.771, 0.488, 0.304, 0.263, 0.247]

# Scatter plot
plt.figure(figsize=(6,4))
plt.scatter(algorithms, accuracy, color='blue')
plt.ylabel('parameters')
plt.title('Algorithm Performance')
plt.xticks(rotation=45)
# Adjusting the limits of the plot axes
plt.xlim(-0.5, len(algorithms)-0.5)
plt.ylim(0, 1)  # assuming accuracy is between 0 and 1

precision=[0.775,0.524,0.389,0.337,0.347]
plt.scatter(algorithms, precision, color='red')
f1=[0.759,0.485,0.344,0.279,0.268]
plt.scatter(algorithms, f1, color='pink')

plt.show()
